# %%
import pandas as pd
import sys
sys.path.insert(0,'../statistics_helper/')
from stats_helper import *
from CI_helper import *

# %%
raw_data = pd.read_excel('../data_20190829.xlsx','Data')

# %%
#CI_sum_prop(estimates=raw_data.loc[raw_data['Kingdom'] == 'Plants','Biomass'].values,mul_CIs=raw_data.loc[raw_data['Kingdom'] == 'Plants','Uncertainty'].values)
def integrate(x):
    x2 = x[['Biomass','Uncertainty']].dropna()
    print(x2)
    return CI_sum_prop(x2['Biomass'].values,x2['Uncertainty'].values)
CI = raw_data.groupby('Kingdom').apply(integrate)
bio = raw_data.groupby('Kingdom')['Biomass'].sum()
agg_res = pd.concat([bio,CI],axis=1)
agg_res.columns = ['Biomass','Uncertainty']
agg_res.loc['fungi','Uncertainty'] = 10
#agg_res.to_csv('data/agg_data.csv')
agg_res
# Out:
#      Biomass  Uncertainty
# 7    0.56451    10.000000
# 11   0.04962    10.000000
# 12      0.05    10.000000
# 14     0.014    10.000000
# 15  0.557122     6.991533
#      Biomass  Uncertainty
# 7    0.56451    10.000000
# 11   0.04962    10.000000
# 12      0.05    10.000000
# 14     0.014    10.000000
# 15  0.557122     6.991533
#     Biomass  Uncertainty
# 6  0.331734     2.688034
#     Biomass  Uncertainty
# 2  0.194478         10.0
#      Biomass  Uncertainty
# 24  0.112355         10.0
#     Biomass  Uncertainty
# 0  0.189737     3.892861
# 1  0.208989     4.657959
# 3  0.103381     3.622760
#      Biomass  Uncertainty
# 4   0.307346     9.254570
# 16     0.592    10.000000
# 17  0.463432     8.263962
# 18       0.1    10.000000
# 19  0.158683    10.000000
# 20  0.208989     4.657959
#           Biomass  Uncertainty
# 25  0.034+/-0.004     2.464433
#      Biomass  Uncertainty
# 7    0.56451    10.000000
# 11   0.04962    10.000000
# 12      0.05    10.000000
# 14     0.014    10.000000
# 15  0.557122     6.991533
#     Biomass  Uncertainty
# 6  0.331734     2.688034
#     Biomass  Uncertainty
# 2  0.194478         10.0
#      Biomass  Uncertainty
# 24  0.112355         10.0
#     Biomass  Uncertainty
# 0  0.189737     3.892861
# 1  0.208989     4.657959
# 3  0.103381     3.622760
#      Biomass  Uncertainty
# 4   0.307346     9.254570
# 16     0.592    10.000000
# 17  0.463432     8.263962
# 18       0.1    10.000000
# 19  0.158683    10.000000
# 20  0.208989     4.657959
#           Biomass  Uncertainty
# 25  0.034+/-0.004     2.464433
#      Biomass  Uncertainty
# 7    0.56451    10.000000
# 11   0.04962    10.000000
# 12      0.05    10.000000
# 14     0.014    10.000000
# 15  0.557122     6.991533
#      Biomass  Uncertainty
# 7    0.56451    10.000000
# 11   0.04962    10.000000
# 12      0.05    10.000000
# 14     0.014    10.000000
# 15  0.557122     6.991533
#     Biomass  Uncertainty
# 6  0.331734     2.688034
#     Biomass  Uncertainty
# 2  0.194478         10.0
#      Biomass  Uncertainty
# 24  0.112355         10.0
#     Biomass  Uncertainty
# 0  0.189737     3.892861
# 1  0.208989     4.657959
# 3  0.103381     3.622760
#      Biomass  Uncertainty
# 4   0.307346     9.254570
# 16     0.592    10.000000
# 17  0.463432     8.263962
# 18       0.1    10.000000
# 19  0.158683    10.000000
# 20  0.208989     4.657959
#           Biomass  Uncertainty
# 25  0.034+/-0.004     2.464433
#      Biomass  Uncertainty
# 7    0.56451    10.000000
# 11   0.04962    10.000000
# 12      0.05    10.000000
# 14     0.014    10.000000
# 15  0.557122     6.991533
#     Biomass  Uncertainty
# 6  0.331734     2.688034
#     Biomass  Uncertainty
# 2  0.194478         10.0
#      Biomass  Uncertainty
# 24  0.112355         10.0
#     Biomass  Uncertainty
# 0  0.189737     3.892861
# 1  0.208989     4.657959
# 3  0.103381     3.622760
#      Biomass  Uncertainty
# 4   0.307346     9.254570
# 16     0.592    10.000000
# 17  0.463432     8.263962
# 18       0.1    10.000000
# 19  0.158683    10.000000
# 20  0.208989     4.657959
#           Biomass  Uncertainty
# 25  0.034+/-0.004     2.464433
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# ~/.local/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# ~/.local/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-12-95b0399c4f91> in integrate(x)
#       4     print(x2)
# ----> 5     return CI_sum_prop(x2['Biomass'].values,x2['Uncertainty'].values)
#       6 CI = raw_data.groupby('Kingdom').apply(integrate)
#
# /mnt/c/Users/admin/Dropbox (Weizmann Institute)/git/milo_lab/ocean_biomass/statistics_helper/CI_helper.py in CI_sum_prop(estimates, mul_CIs)
#      30         # This generates an array with N rows and 1000 columns, where N is the number of estimates in the argument estimates
# ---> 31         sample = np.random.lognormal(mean = np.log(estimate), sigma = np.log(mul_CIs[ind])/1.96,size=sample_size).reshape([1,-1])
#      32         data = np.vstack((data,sample))
#
# TypeError: ufunc 'log' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-95b0399c4f91> in <module>
#       4     print(x2)
#       5     return CI_sum_prop(x2['Biomass'].values,x2['Uncertainty'].values)
# ----> 6 CI = raw_data.groupby('Kingdom').apply(integrate)
#       7 bio = raw_data.groupby('Kingdom')['Biomass'].sum()
#       8 agg_res = pd.concat([bio,CI],axis=1)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# ~/.local/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/.local/lib/python3.5/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# <ipython-input-12-95b0399c4f91> in integrate(x)
#       3     x2 = x[['Biomass','Uncertainty']].dropna()
#       4     print(x2)
# ----> 5     return CI_sum_prop(x2['Biomass'].values,x2['Uncertainty'].values)
#       6 CI = raw_data.groupby('Kingdom').apply(integrate)
#       7 bio = raw_data.groupby('Kingdom')['Biomass'].sum()
#
# /mnt/c/Users/admin/Dropbox (Weizmann Institute)/git/milo_lab/ocean_biomass/statistics_helper/CI_helper.py in CI_sum_prop(estimates, mul_CIs)
#      29         # For each estimate, sample 1000 samples from a lognormal distribution with a mean of log(estimate) and std of log(95_CI)/1.96
#      30         # This generates an array with N rows and 1000 columns, where N is the number of estimates in the argument estimates
# ---> 31         sample = np.random.lognormal(mean = np.log(estimate), sigma = np.log(mul_CIs[ind])/1.96,size=sample_size).reshape([1,-1])
#      32         data = np.vstack((data,sample))
#      33
#
# TypeError: ufunc 'log' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

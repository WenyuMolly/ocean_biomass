# %%
import pandas as pd
import sys
sys.path.insert(0,'../statistics_helper/')
from stats_helper import *
from CI_helper import *

# %% [markdown]
# ## Run code

# %%
# %run ./fish_biomass_estimate.ipynb
# Out:
# Our best estimate for the biomass of mesopelagic fish based on acoustic measurements is 9.8 Gt wet weight
# Our best estimate for the wet biomass of mesopelagic fish is ≈3.1 Gt wet weight
# Our best estimate for the biomass of mesopelagic fish is ≈0.4 Gt C
# Our best estimate for the biomass of fish is ≈0.6 Gt C
# Our projection for the uncertainty associated with the choice of scenario regarding the fraction of mesopelagic fish with gas-filled swim bladder is 1.6-fold
# Our best projection for the inter method uncertainty associated with estimate of the biomass of mesopelagic fish is ≈9.3-fold
# Our best projection for the uncertainty associated with the estimate of the biomass of fish is ≈7-fold

# %%
# %run ./marine_fungi.ipynb
# Out:
# The ratio of fungal DNA copy number and bacterial DNA copy number is ≈12%
# The ratio of fungal carbon and bacterial carbon is ≈27%
# The ratio of fungal carbon and bacterial carbon is ≈18%
# Our estimate for the total biomass of bacteria and archaea in the epipelagic layer is ≈0.5 Gt C
# Our estimate for the total biomass of free-living epipelagic fungi based of qPCR is ≈0.09 Gt C
# Our best estimate for the biomass of deep-sea microbial eukaryotes is ≈0.11 Gt C
# Our estimate of the biomass of deep-sea fungi based on 18S rDNA sequencing is ≈0.02 Gt C
# Our estimate of the biomass of deep-sea fungi based on the ratio between fungal and prokaryote biomass is ≈0.20 Gt C
# Our best estimate of the biomass of deep-sea fungi is ≈0.06 Gt C
# Our best estimate of the ratio between the biomass of particle-attached fungi and prokaryotes in the bathypelagic layer is ≈0.7
# Our best estimate of the total biomass of fungi attached to macroaggregates is ≈0.1 Gt C
# Our best estimate of the total biomass of particle-attached fungi is ≈0.1 Gt C
# Our best estimate of the total biomass of marine fungi is ≈0.3 Gt C

# %%
# %run ./phytoplankton.ipynb
# Out:
# We estimate the global biomass of picophytoplankton based on our bottom-up approach at ≈0.4 Gt C
# We estimate the global biomass of diatoms based on our bottom-up approach at ≈0.3 Gt C
# We estimate the global biomass of Phaeocystis based on our bottom-up approach at ≈0.3 Gt C
# We estimate the global biomass of phytoplankton based on our bottom-up approach at ≈1.1 Gt C
# We estimate the global biomass of green microalgae based on our bottom-up approach at ≈0.06 Gt C
# We estimate the global biomass of cyanobacteria based on our top-down approach at ≈0.2 Gt C
# We estimate the global biomass of protist phytoplankton based on our bottom-up approach at ≈0.12 Gt C
# Our best estimate for the global biomass of cyanobacteria is ≈0.2 Gt C
# Our best estimate for the global biomass of plant phytoplankton is ≈0.1 Gt C
# Our best estimate for the global biomass of protist phytoplankton is ≈0.3 Gt C
# Our best projection for the uncertainty associated with our estimate of the global biomass of plant phytoplankton is ≈2.9-fold
# Our best projection for the uncertainty associated with our estimate of the global biomass of protist phytoplankton is ≈6.3-fold

# %%
# %run ./plants.ipynb
# Out:
# Our best estimate for the biomass density of seagrasses is 158 g C m^-2
# Our best estimate for the total biomass of seagrasses is ≈0.2 Gt C
# Our best estimate for the global range of macroalgae is 2.8E+12 m^2
# gmean: 117.8249486348216
# arithmetic mean: 185.80942793027253
# Our best estimate for the average biomass density of macroalgae is ≈148 g C m^-2
# Our best estimate for the global biomass of macroalgae is ≈0.4 Gt C
# Our best estimate for the global biomass of macroalgae is ≈0.5 Gt C
# Our best projection of the uncertainty associated with our estimate of the biomass of seagrasses is ≈3-fold
# Our best projection of the uncertainty associated with our estimate of the biomass of macroalgae is ≈2-fold
# Our best projection of the uncertainty associated with our estimate of the biomass of marine plants is ≈2.2-fold

# %%
# %run ./virus_biomass_estimate.ipynb
# Out:
# ./virus_biomass_estimate.ipynb:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   {
# ./virus_biomass_estimate.ipynb:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   {
# /home/yinonbaron/.local/lib/python3.5/site-packages/scipy/optimize/minpack.py:785: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# Our best estimate for the total number of viruses in the ocean is 1.5e+30 viruses
# Our best estimate for the radius of a phage is ≈26 nm.
# Our best estimate for the carbon content of a single phage is ≈   2.3e-17+/-   0.3e-17 g
# Our best estimate for the total biomass of marine phages is ≈0.03 Gt C
# Our projection for the uncertainty associated with our estimate for the total number of marine viruses is 1.5-fold
# The intra site uncertainty in the radius of phages is ≈1.4-fold
# The intra sample uncertainty in the radius of phages is ≈1.02-fold
# Our best estimate for the uncertainty of the carbon content of a single phage stemming from the uncertainty in our estimate for the radius of a single phage is ≈2.2-fold
# The uncertainty associated with the parameters of the model is 1.2-fold
# Our best projection for the uncertainty associated with the carbon content of a single phage is ≈2.2-fold
# Our best projection of the uncertainty associated with our estimate for the total biomass of marine viruses is 2.4-fold

# %%
# %run ./marine_protists.ipynb
# Out:
# Our best estimate of the ratio between heterotrophic and phototrophic protists in pico-nanoplankton is ≈2-fold
# Our best estimate for the biomass of heterotrophic pico-nanoplankton is ≈0.25 Gt C
# Our best estimate for the biomass of microzooplankton is ≈0.6 Gt C
# Our best estimate for the biomass of rhizaria is ≈0.5 Gt C
# Our best estimate for the biomass of planktonic protists is ≈1.6 Gt C
# The mean ratio between the number of particle-attached protists and prokaryotes reported in Bochdansky et al. is ≈0.004
# Our best estimate for the biomass ratio between particle-attached protists and prokaryotes in the bathypelagic layer is ≈1.3
# Our estimate for the ratio between the biomass of particle-attached protists and prokaryotes based on Herndl is ≈2.7
# Our best estimate for the biomass ratio between particle-attached protists and prokaryotes is ≈1.1
# Our best estimate for the total biomass of protists in marine snow is ≈0.13 Gt C
# Our best estimate for the total biomass of marine protists is ≈2.0 Gt C
# ./marine_protists.ipynb:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   "execution_count": 1,
# Our best projection of the biomass of marine protists is ≈3-fold

# %%
raw_data = pd.read_excel('../results/results.xlsx','Data')

# %%
raw_data
# Out:
#                                   Taxon   Kingdom     Group Cellularity  \
# 0                              Seagrass    plants       NaN       Multi
# 1                      Plant macroalgae    plants       NaN       Multi
# 2               Bacterial phytoplankton  bacteria       NaN         Uni
# 3             Green algae phytoplankton    plants       NaN         Uni
# 4                 Protist phytoplankton  protists       NaN         Uni
# 5                       Marine bacteria  bacteria       NaN         Uni
# 6                        Marine archaea   archaea       NaN         Uni
# 7                       Mesozooplankton   animals  Copepods       Multi
# 8   Macrozooplankton (only crustaceans)   animals       NaN       Multi
# 9                             Pteropods   animals       NaN       Multi
# 10                 Cnidaria (jellyfish)   animals       NaN       Multi
# 11                    Cnidaria (corals)   animals       NaN       Multi
# 12                     Molluscs (squid)   animals       NaN       Multi
# 13                  Wild marine mammals   animals       NaN       Multi
# 14                            Nematodes   animals       NaN       Multi
# 15                                 Fish   animals      Fish       Multi
# 16                     Microzooplankton  protists       NaN         Uni
# 17                             Rhizaria  protists       NaN         Uni
# 18                     Deep sea protist  protists       NaN         Uni
# 19           Particle attached protists  protists       NaN         Uni
# 20                   Protist macroalgae  protists       NaN       Multi
# 21      Heterotrophic pico-nanoplankton  protists       NaN         Uni
# 22                     Epipelagic fungi     fungi       NaN         Uni
# 23                       Deep sea fungi     fungi       NaN         Uni
# 24              Particle attached fungi     fungi       NaN         Uni
# 25                              Viruses   viruses       NaN         Uni
#
#     Location Trophic mode  Biomass  Uncertainty      Reference
# 0    Benthic         Auto      0.2          3.1     This study
# 1    Benthic         Auto      0.2          2.4     This study
# 2   Plankton         Auto      0.2          nan     This study
# 3   Plankton         Auto      0.1         10.0     This study
# 4   Plankton         Auto      0.3          6.3     This study
# 5   Plankton       Hetero      1.1          1.8  Bar-On et al.
# 6   Plankton       Hetero      0.3          2.7  Bar-On et al.
# 7   Plankton       Hetero      0.6         10.0  Bar-On et al.
# 8   Plankton       Hetero      0.4         10.0  Bar-On et al.
# 9   Plankton       Hetero      0.1         10.0  Bar-On et al.
# 10  Plankton       Hetero      0.0         10.0  Bar-On et al.
# 11   Benthic       Hetero      0.0         10.0  Bar-On et al.
# 12    Nekton       Hetero      0.1         10.0  Bar-On et al.
# 13    Nekton       Hetero      0.0          nan  Bar-On et al.
# 14   Benthic       Hetero      0.0         10.0  Bar-On et al.
# 15    Nekton       Hetero      0.6          7.1     This study
# 16  Plankton       Hetero      0.6         10.0  Bar-On et al.
# 17  Plankton       Hetero      0.5          1.2     This study
# 18  Plankton       Hetero      0.1          nan  Bar-On et al.
# 19  Particle       Hetero      0.2         10.0     This study
# 20   Benthic         Auto      0.2          2.4     This study
# 21  Plankton       Hetero      0.2          nan     This study
# 22  Plankton       Hetero      0.1          nan     This study
# 23  Plankton       Hetero      0.1          nan     This study
# 24  Particle       Hetero      0.1         10.0     This study
# 25  Plankton       Hetero      0.0          2.4     This study

# %%
#CI_sum_prop(estimates=raw_data.loc[raw_data['Kingdom'] == 'Plants','Biomass'].values,mul_CIs=raw_data.loc[raw_data['Kingdom'] == 'Plants','Uncertainty'].values)
def integrate(x):
    x2 = x[['Biomass','Uncertainty']].dropna()
    
    return CI_sum_prop(x2['Biomass'].values,x2['Uncertainty'].values)
CI = raw_data.groupby('Kingdom').apply(integrate)
bio = raw_data.groupby('Kingdom')['Biomass'].sum()
agg_res = pd.concat([bio,CI],axis=1)
agg_res.columns = ['Biomass','Uncertainty']
agg_res.loc['fungi','Uncertainty'] = 10
agg_res.loc['bacteria','Uncertainty'] = 3
agg_res.loc['archaea','Uncertainty'] = 3
agg_res.to_csv('../results/agg_data.csv')

# %%
agg_res
# Out:
#           Biomass  Uncertainty
# Kingdom
# animals       1.8          3.3
# archaea       0.3          2.7
# bacteria      1.3          1.8
# fungi         0.3         10.0
# plants        0.5          2.4
# protists      2.1          2.8
# viruses       0.0          2.5
